# %%
import json
import pandas as pd
import requests

# %%
api_key = 'NCQaVZa6lgUirpqBxe4DQLzRrW7Tdjhx855u-brqO6rRS0ybfaza-wsk-hMF9Kc7SrLTEjtOvLusLrjdJZ-JPlxg1TZ1LgL9caVilD1Zo2B7K7M0EZdziP0SCrcpZXYx'

# URL to pull data from:
url = 'https://api.yelp.com/v3/businesses/search'

# Identify headers:
headers = {'Authorization': 'Bearer {}'.format(api_key)}

# %%
cruisines = ['Indian', 'Chinese', 'Italian']
# Create temporary dataframe to hold data:
nyc = [[] for i in range(len(cruisines))]

# %%
# Function to draw in data for each neighborhood:
for x in range(len(nyc)):
    print('---------------------------------------------')
    print('Gathering Data for {}'.format(cruisines[x]))
    print('---------------------------------------------')


    for y in range(20):
        location = 'Manhattan, NY'
        term = cruisines[x] + " Restaurants"
        search_limit = 50
        offset = 50 * y
        categories = "(restaurants, All)"
        sort_by = 'distance'

        url_params = {
                        'location': location.replace(' ', '+'),
                        'term' : term,
                        'limit': search_limit,
                        'offset': offset,
                        'categories': categories,
                        'sorty_by': sort_by
                    }
        
        response = requests.get(url, headers=headers, params=url_params)
        print('***** {} Restaurants #{} - #{} ....{}'.format(cruisines[x], 
                                                             offset+1, offset+search_limit,
                                                             response))
        nyc[x].append(response)

print(response)
print(type(response.text))
print(response.json().keys())
print(response.text[:1000])
# Out:
# ---------------------------------------------
# Gathering Data for Indian
# ---------------------------------------------
# ***** Indian Restaurants #1 - #50 ....<Response [200]>
# ***** Indian Restaurants #51 - #100 ....<Response [200]>
# ***** Indian Restaurants #101 - #150 ....<Response [200]>
# ***** Indian Restaurants #151 - #200 ....<Response [200]>
# ***** Indian Restaurants #201 - #250 ....<Response [200]>
# ***** Indian Restaurants #251 - #300 ....<Response [200]>
# ***** Indian Restaurants #301 - #350 ....<Response [200]>
# ***** Indian Restaurants #351 - #400 ....<Response [200]>
# ***** Indian Restaurants #401 - #450 ....<Response [200]>
# ***** Indian Restaurants #451 - #500 ....<Response [200]>
# ***** Indian Restaurants #501 - #550 ....<Response [200]>
# ***** Indian Restaurants #551 - #600 ....<Response [200]>
# ***** Indian Restaurants #601 - #650 ....<Response [200]>
# ***** Indian Restaurants #651 - #700 ....<Response [200]>
# ***** Indian Restaurants #701 - #750 ....<Response [200]>
# ***** Indian Restaurants #751 - #800 ....<Response [200]>
# ***** Indian Restaurants #801 - #850 ....<Response [200]>
# ***** Indian Restaurants #851 - #900 ....<Response [200]>
# ***** Indian Restaurants #901 - #950 ....<Response [200]>
# ***** Indian Restaurants #951 - #1000 ....<Response [200]>
# ---------------------------------------------
# Gathering Data for Chinese
# ---------------------------------------------
# ***** Chinese Restaurants #1 - #50 ....<Response [200]>
# ***** Chinese Restaurants #51 - #100 ....<Response [200]>
# ***** Chinese Restaurants #101 - #150 ....<Response [200]>
# ***** Chinese Restaurants #151 - #200 ....<Response [200]>
# ***** Chinese Restaurants #201 - #250 ....<Response [200]>
# ***** Chinese Restaurants #251 - #300 ....<Response [200]>
# ***** Chinese Restaurants #301 - #350 ....<Response [200]>
# ***** Chinese Restaurants #351 - #400 ....<Response [200]>
# ***** Chinese Restaurants #401 - #450 ....<Response [200]>
# ***** Chinese Restaurants #451 - #500 ....<Response [200]>
# ***** Chinese Restaurants #501 - #550 ....<Response [200]>
# ***** Chinese Restaurants #551 - #600 ....<Response [200]>
# ***** Chinese Restaurants #601 - #650 ....<Response [200]>
# ***** Chinese Restaurants #651 - #700 ....<Response [200]>
# ***** Chinese Restaurants #701 - #750 ....<Response [200]>
# ***** Chinese Restaurants #751 - #800 ....<Response [200]>
# ***** Chinese Restaurants #801 - #850 ....<Response [200]>
# ***** Chinese Restaurants #851 - #900 ....<Response [200]>
# ***** Chinese Restaurants #901 - #950 ....<Response [200]>
# ***** Chinese Restaurants #951 - #1000 ....<Response [200]>
# ---------------------------------------------
# Gathering Data for Italian
# ---------------------------------------------
# ***** Italian Restaurants #1 - #50 ....<Response [200]>
# ***** Italian Restaurants #51 - #100 ....<Response [200]>
# ***** Italian Restaurants #101 - #150 ....<Response [200]>
# ***** Italian Restaurants #151 - #200 ....<Response [200]>
# ***** Italian Restaurants #201 - #250 ....<Response [200]>
# ***** Italian Restaurants #251 - #300 ....<Response [200]>
# ***** Italian Restaurants #301 - #350 ....<Response [200]>
# ***** Italian Restaurants #351 - #400 ....<Response [200]>
# ***** Italian Restaurants #401 - #450 ....<Response [200]>
# ***** Italian Restaurants #451 - #500 ....<Response [200]>
# ***** Italian Restaurants #501 - #550 ....<Response [200]>
# ***** Italian Restaurants #551 - #600 ....<Response [200]>
# ***** Italian Restaurants #601 - #650 ....<Response [200]>
# ***** Italian Restaurants #651 - #700 ....<Response [200]>
# ***** Italian Restaurants #701 - #750 ....<Response [200]>
# ***** Italian Restaurants #751 - #800 ....<Response [200]>
# ***** Italian Restaurants #801 - #850 ....<Response [200]>
# ***** Italian Restaurants #851 - #900 ....<Response [200]>
# ***** Italian Restaurants #901 - #950 ....<Response [200]>
# ***** Italian Restaurants #951 - #1000 ....<Response [200]>
# <Response [200]>
# <class 'str'>
# dict_keys(['businesses', 'total', 'region'])
# {"businesses": [{"id": "C88t-slddgUHNJKEheQ-EA", "alias": "mi-garba-new-york-2", "name": "Mi Garba", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/16jWS1hYgvbQmuSnY4a8oQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/mi-garba-new-york-2?adjust_creative=6OZ1_Xj7wQkWP6IaEY5kkQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6OZ1_Xj7wQkWP6IaEY5kkQ", "review_count": 5, "categories": [{"alias": "salad", "title": "Salad"}, {"alias": "wine_bars", "title": "Wine Bars"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 5.0, "coordinates": {"latitude": 40.7327, "longitude": -74.00397}, "transactions": [], "location": {"address1": "310 Bleecker St", "address2": "", "address3": null, "city": "New York", "zip_code": "10014", "country": "US", "state": "NY", "display_address": ["310 Bleecker St", "New York, NY 10014"]}, "phone": "+16464906125", "display_phone": "(646) 490-6125", "distance": 3741.5910696087485}, {"id": "ipoJv9uuT3WgjeVozKUx8A"

# %%
## Check for any empty business lists:
for x in range(len(cruisines)):
    for y in range(20):
        num1 = nyc[x][y].json().get('businesses', [])
        num = len(num1)
        if num != 50:
            print(cruisines[x], x, y, num)
# Out:
# Indian 0 18 10
# Indian 0 19 0

# %%
## Save the compiled data into dataframe and remove any empty data:
df = pd.DataFrame()
for x in range(len(cruisines)):
    if x == 0: # Little Italy has a total of 486 restaurants
        for y in range(19):
            df_temp = pd.DataFrame.from_dict(nyc[x][y].json()['businesses'])
            df_temp.loc[:,'cruisine'] = cruisines[x]
            df = df.append(df_temp)
    else:
        for y in range(20):
            df_temp = pd.DataFrame.from_dict(nyc[x][y].json()['businesses'])
            df_temp.loc[:,'cruisine'] = cruisines[x]
            df = df.append(df_temp)
# Out:
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)
# /var/folders/df/s2jfckq56x7_h042b7y8vxkc0000gn/T/ipykernel_45318/1649749480.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp)

# %%
df
# Out:
#                         id                                alias  \
# 0   x0k5kFArHLijdY8-NEQ7Xg    bengal-tiger-indian-food-new-york
# 1   1_pK5aQ47atF50oAKHADhA               indian-accent-new-york
# 2   z2VXX7wGl8XZ6_oo9W3koA        patiala-indian-grill-new-york
# 3   HEs6llkn3wIP1ATXeIZQew                     pippali-new-york
# 4   XLEdQl5s1bO5Iu43W_c96Q                      muna-new-york-2
# ..                     ...                                  ...
# 45  gkoAJruMnKVuoKVqorgFCA  trovo-nyc-thin-crust-pizza-new-york
# 46  5Ucd5yN_VFlMkhG3QYV2Ng            piu-bella-east-elmhurst-2
# 47  7KtUcXF28tDEv8CBbgWNJw                  bar-felice-new-york
# 48  cTE0e96GYzet799EJeStoQ          chama-mama-chelsea-new-york
# 49  B-Bssflz-SxmH0fVSat8tg              the-perry-club-new-york
#
#                           name  \
# 0     Bengal Tiger Indian Food
# 1                Indian Accent
# 2         Patiala Indian Grill
# 3                      Pippali
# 4                         Muna
# ..                         ...
# 45  TROVO NYC Thin Crust Pizza
# 46                   Piu Bella
# 47                  Bar Felice
# 48        Chama Mama - Chelsea
# 49              The Perry Club
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/65Q6vt...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/tnHSNw...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/cFmz8I...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/B9NtMk...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/NM7mXP...      False
# ..                                                ...        ...
# 45  https://s3-media2.fl.yelpcdn.com/bphoto/UZBaD0...      False
# 46  https://s3-media2.fl.yelpcdn.com/bphoto/bWEsuQ...      False
# 47  https://s3-media4.fl.yelpcdn.com/bphoto/6WwHix...      False
# 48  https://s3-media1.fl.yelpcdn.com/bphoto/Fg6_8i...      False
# 49  https://s3-media2.fl.yelpcdn.com/bphoto/v6VyXX...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/bengal-tiger-indian-f...          2326
# 1   https://www.yelp.com/biz/indian-accent-new-yor...           716
# 2   https://www.yelp.com/biz/patiala-indian-grill-...           624
# 3   https://www.yelp.com/biz/pippali-new-york?adju...           897
# 4   https://www.yelp.com/biz/muna-new-york-2?adjus...            39
# ..                                                ...           ...
# 45  https://www.yelp.com/biz/trovo-nyc-thin-crust-...             9
# 46  https://www.yelp.com/biz/piu-bella-east-elmhur...            78
# 47  https://www.yelp.com/biz/bar-felice-new-york?a...            33
# 48  https://www.yelp.com/biz/chama-mama-chelsea-ne...           694
# 49  https://www.yelp.com/biz/the-perry-club-new-yo...            55
#
#                                            categories  rating  \
# 0            [{'alias': 'indpak', 'title': 'Indian'}]     4.5
# 1            [{'alias': 'indpak', 'title': 'Indian'}]     4.5
# 2            [{'alias': 'indpak', 'title': 'Indian'}]     4.5
# 3            [{'alias': 'indpak', 'title': 'Indian'}]     4.0
# 4   [{'alias': 'himalayan', 'title': 'Himalayan/Ne...     4.5
# ..                                                ...     ...
# 45  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.5
# 46         [{'alias': 'italian', 'title': 'Italian'}]     4.5
# 47  [{'alias': 'lounges', 'title': 'Lounges'}, {'a...     4.0
# 48  [{'alias': 'georgian', 'title': 'Georgian'}, {...     4.5
# 49  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
#
#                                           coordinates  \
# 0    {'latitude': 40.763167, 'longitude': -73.977131}
# 1   {'latitude': 40.7643344624229, 'longitude': -7...
# 2   {'latitude': 40.7534700430117, 'longitude': -7...
# 3      {'latitude': 40.74233, 'longitude': -73.98331}
# 4    {'latitude': 40.753509, 'longitude': -73.973515}
# ..                                                ...
# 45      {'latitude': 40.7589, 'longitude': -73.96875}
# 46   {'latitude': 40.770577, 'longitude': -73.890185}
# 47   {'latitude': 40.7748027, 'longitude': -73.95113}
# 48      {'latitude': 40.7384, 'longitude': -73.99892}
# 49     {'latitude': 40.73562, 'longitude': -74.00144}
#
#                                   transactions price  \
# 0                           [delivery, pickup]    $$
# 1                           [delivery, pickup]  $$$$
# 2                           [delivery, pickup]    $$
# 3   [delivery, restaurant_reservation, pickup]    $$
# 4                           [delivery, pickup]   NaN
# ..                                         ...   ...
# 45                          [delivery, pickup]   NaN
# 46                          [delivery, pickup]    $$
# 47                                          []   $$$
# 48                          [delivery, pickup]    $$
# 49                          [delivery, pickup]   NaN
#
#                                              location         phone  \
# 0   {'address1': '58 W 56th St', 'address2': 'Fl 2...  +12122652703
# 1   {'address1': '123 W 56th St', 'address2': '', ...  +12128428070
# 2   {'address1': '371 W 34th St', 'address2': '', ...  +12125648255
# 3   {'address1': '129 E 27th St', 'address2': '', ...  +12126891999
# 4   {'address1': '152 East 46th St', 'address2': N...  +16463987960
# ..                                                ...           ...
# 45  {'address1': '906 3rd Ave', 'address2': '', 'a...  +19174512220
# 46  {'address1': '79-16 21st Ave', 'address2': Non...  +17187216500
# 47  {'address1': '1591 1st Ave', 'address2': '', '...  +12122494080
# 48  {'address1': '149 W 14th St', 'address2': None...  +16464389007
# 49  {'address1': '157 7th Ave S', 'address2': None...  +12124070411
#
#      display_phone     distance cruisine
# 0   (212) 265-2703   347.928123   Indian
# 1   (212) 842-8070   458.485419   Indian
# 2   (212) 564-8255  1650.105507   Indian
# 3   (212) 689-1999  2027.800612   Indian
# 4   (646) 398-7960   854.718729   Indian
# ..             ...          ...      ...
# 45  (917) 451-2220   816.241098  Italian
# 46  (718) 721-6500  7525.384774  Italian
# 47  (212) 249-4080  2818.542352  Italian
# 48  (646) 438-9007  2966.180331  Italian
# 49  (212) 407-0411  3362.207567  Italian
#
# [2910 rows x 17 columns]

# %%
# df.to_csv('yelp_data_by_cruisine.csv', sep='\t', encoding='utf-8')
df.shape
# Out:
# (2910, 17)

# %%
print(len(df['name'].unique()))
# Out:
# 2692

# %%
# Delete duplicate rows based on specific columns 
df2 = df.drop_duplicates(subset=["name"], keep='first')
print(len(df2['name'].unique()))
# Out:
# 2692

# %%
print(len(df2['name']))
df2.to_csv('yelp_data_by_cruisine.csv', sep='\t', encoding='utf-8')
# Out:
# 2692

# %%
# df3 = df2
# df3['json'] = df2.apply(lambda x: x.to_json(), axis=1)

# %%
# df3['json']
